# %%
from requests_oauthlib import OAuth1Session
import json
import datetime, time, sys
import key

session = OAuth1Session(key.CK, key.CS, key.AT, key.AS)
key_words = u'#python'
url = 'https://api.twitter.com/1.1/search/tweets.json'
res = session.get(url, params = {'q':key_words, 'count':30})

if res.status_code != 200:
    print ("Twitter API Error: %d" % res.status_code)
    sys.exit(1)
    
print('アクセス可能回数 %s' % res.headers['X-Rate-Limit-Remaining'])
print('リセット時間 %s' % res.headers['X-Rate-Limit-Reset'])
sec =int(res.headers['X-Rate-Limit-Reset'])\
           - time.mktime(datetime.datetime.now().timetuple())
print('リセット時間 （残り秒数に換算） %s' % sec)
 

res_text = json.loads(res.text)
for tweet in res_text['statuses']:
    print ('--------------------------------------------------------------')
    print('account:',"(fullname:",tweet['user']['name'],'href:',("/"+tweet['user']['screen_name']).strip(),"id:",tweet['user']['id'],')')
    print ("date:",tweet['created_at'])
    print("hashtags:",key_words)
    print(tweet['favorite_count'])
    print(tweet['retweet_count'])
    print (tweet['text'])
# Out:
# アクセス可能回数 179
# リセット時間 1542189182
# リセット時間 （残り秒数に換算） 900.0
# --------------------------------------------------------------
# account: (fullname: Bilan Codes href: /BilanCodes id: 981073622054965249 )
# date: Wed Nov 14 09:36:36 +0000 2018
# hashtags: #python
# 0
# 9
# RT @munniomer: #Day33_38 of #100daysofcode
# It was a week full of errors 😏 but yeah finally managed to build some of the #APIs of my APP us…
# --------------------------------------------------------------
# account: (fullname: よーろ@フリーランスエンジニア宣言 href: /YOLO_pippi id: 983840051187470336 )
# date: Wed Nov 14 09:35:03 +0000 2018
# hashtags: #python
# 0
# 0
# 水曜日は定時ダッシュ！
# マックでPyQが自分にぴったりの最強の勉強法。騒がしい方が集中できるのはなぜなのか・・
# #Python https://t.co/8qOjVEhjLG
# --------------------------------------------------------------
# account: (fullname: Newton Munene href: /newtonmunene_yg id: 923835703913414656 )
# date: Wed Nov 14 09:34:50 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: Newton Munene href: /newtonmunene_yg id: 923835703913414656 )
# date: Wed Nov 14 09:34:50 +0000 2018
# hashtags: #python
# 0
# 2
# RT @JansherRahman: CSS and Network Performance
# https://t.co/ndwyEjmpI8 #css #html #javascript #programming #webdesign #coding #programmer #…
# --------------------------------------------------------------
# account: (fullname: Newton Munene href: /newtonmunene_yg id: 923835703913414656 )
# date: Wed Nov 14 09:34:50 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: Newton Munene href: /newtonmunene_yg id: 923835703913414656 )
# date: Wed Nov 14 09:34:50 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: digital mine ⚡🤖👨‍💻 href: /digital_mine_ id: 2394249235 )
# date: Wed Nov 14 09:34:45 +0000 2018
# hashtags: #python
# 0
# 1
# Text predictor for #AI #machinelearning
# https://t.co/sNMCp7lOgT
# #deeplearn #code #developer #python #bitcoin #btc… https://t.co/uwwyOSqV4A
# --------------------------------------------------------------
# account: (fullname: Julius Tanuwijaya href: /Julius_Hin id: 169920273 )
# date: Wed Nov 14 09:34:43 +0000 2018
# hashtags: #python
# 0
# 6
# RT @linuxjournal: Automate Sysadmin Tasks with Python's os.walk Function by @reuvenmlerner. Using Python's os.walk function to walk through…
# --------------------------------------------------------------
# account: (fullname: Codonomics href: /codonomics id: 119328096 )
# date: Wed Nov 14 09:34:03 +0000 2018
# hashtags: #python
# 0
# 0
# Can't install #Python wrapper for #VowpalWabbit on #Windows. It hurts to be on windows for reasons aplenty and this… https://t.co/8CMvpjwNOr
# --------------------------------------------------------------
# account: (fullname: Jansher Rahman href: /JansherRahman id: 944856463410900992 )
# date: Wed Nov 14 09:33:37 +0000 2018
# hashtags: #python
# 1
# 2
# CSS and Network Performance
# https://t.co/ndwyEjmpI8 #css #html #javascript #programming #webdesign #coding… https://t.co/YXodcZlGq2
# --------------------------------------------------------------
# account: (fullname: Marie Fontanel href: /M_FONTANEL id: 251653052 )
# date: Wed Nov 14 09:33:10 +0000 2018
# hashtags: #python
# 0
# 3
# RT @DjangoGirlsFr26: 🦄🦄 Les inscriptions sont ouvertes 🦄🦄
# https://t.co/jYOCUsaU0m
# Venez au @CampusAlps découvrir la programmation et créer…
# --------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 09:32:55 +0000 2018
# hashtags: #python
# 0
# 1
# RT @PythonPosts: Using Django with service workers
# https://t.co/F9J0Faf2Ps
# 2016-04-01
# @PyvideoOrg
# #python https://t.co/Hl4AGVVnpa
# --------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 09:32:54 +0000 2018
# hashtags: #python
# 0
# 1
# RT @G2cKaouther: Let's Discover #Python with G2C
# 📞 +216 29 830 649
# 📧 g2c.formation02@gmail.com
# #Lear to #program in #Python
# session around…
# --------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 09:32:54 +0000 2018
# hashtags: #python
# 0
# 1
# RT @j2logo: ScrapydWeb: Full-featured web UI for Scrapyd cluster management, Scrapy log analysis &amp; visualization #python
# --------------------------------------------------------------
# account: (fullname: Xavier dePedroPuente href: /xavierdepedro id: 416522119 )
# date: Wed Nov 14 09:32:33 +0000 2018
# hashtags: #python
# 0
# 0
# S'està promovent un espai x compartir, relacionat amb l'anàlisi dades d'utilitat pública. 1a trobada 18/12/18. Patí… https://t.co/QSu24d0UiZ
# --------------------------------------------------------------
# account: (fullname: Ross O'Brien href: /full_stache_dev id: 3428432883 )
# date: Wed Nov 14 09:31:32 +0000 2018
# hashtags: #python
# 0
# 3
# RT @espindoladah: Day 034/100:
#
# My classes on college returned, so I came back to #Python fundamentals part one and the old "hello world" j…
# --------------------------------------------------------------
# account: (fullname: Ross O'Brien href: /full_stache_dev id: 3428432883 )
# date: Wed Nov 14 09:31:32 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: Ross O'Brien href: /full_stache_dev id: 3428432883 )
# date: Wed Nov 14 09:31:32 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: Ross O'Brien href: /full_stache_dev id: 3428432883 )
# date: Wed Nov 14 09:31:32 +0000 2018
# hashtags: #python
# 0
# 3
# RT @espindoladah: Day 034/100:
#
# My classes on college returned, so I came back to #Python fundamentals part one and the old "hello world" j…
# --------------------------------------------------------------
# account: (fullname: Ross O'Brien href: /full_stache_dev id: 3428432883 )
# date: Wed Nov 14 09:31:32 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: Online Course Offer href: /OnlineCourse247 id: 992540358079741952 )
# date: Wed Nov 14 09:31:15 +0000 2018
# hashtags: #python
# 0
# 1
# RT @GinaDGreen1: #udemy #udemydiscounts #udemydeals #udemyfree #onlinecourses #python #development
# [Udemy 100% Free]-Python: Everything yo…
# --------------------------------------------------------------
# account: (fullname: Vishnu Priya href: /vishn_u99 id: 1035175128273838080 )
# date: Wed Nov 14 09:31:02 +0000 2018
# hashtags: #python
# 0
# 3
# RT @byLilyV: Want to learn the latest technologies for building great web applications?
# Enrol in
# #Python and #Django FullStack Web Develope…
# --------------------------------------------------------------
# account: (fullname: Sebastian Nickel href: /sbstn_nckl id: 12803672 )
# date: Wed Nov 14 09:30:59 +0000 2018
# hashtags: #python
# 0
# 1
# RT @GLD_Gothenburg: We are looking for a #DataScientist! Permanent position in beautiful Gothenburg. Working in an awesome project about lo…
# --------------------------------------------------------------
# account: (fullname: 🤖 #100DAYSOFCODE href: /100xcode id: 1000814755664150528 )
# date: Wed Nov 14 09:30:45 +0000 2018
# hashtags: #python
# 0
# 3
# RT @espindoladah: Day 034/100:
#
# My classes on college returned, so I came back to #Python fundamentals part one and the old "hello world" j…
# --------------------------------------------------------------
# account: (fullname: Dah href: /espindoladah id: 76509165 )
# date: Wed Nov 14 09:30:39 +0000 2018
# hashtags: #python
# 2
# 3
# Day 034/100:
#
# My classes on college returned, so I came back to #Python fundamentals part one and the old "hello wo… https://t.co/XjROklbhCP
# --------------------------------------------------------------
# account: (fullname: Coopt-Action.fr href: /CooptAction id: 2421665066 )
# date: Wed Nov 14 09:30:23 +0000 2018
# hashtags: #python
# 0
# 0
# #Emploi - #Ingénieur #Développement (#PHP, #Java ee, .net, #Python). https://t.co/uGBnyPDHLo https://t.co/a1lQynFAOO
# --------------------------------------------------------------
# account: (fullname: Juan José Lozano Gómez href: /j2logo id: 218642028 )
# date: Wed Nov 14 09:30:00 +0000 2018
# hashtags: #python
# 1
# 1
# ScrapydWeb: Full-featured web UI for Scrapyd cluster management, Scrapy log analysis &amp; visualization #python
# --------------------------------------------------------------
# account: (fullname: GLD href: /GLD_Gothenburg id: 798476949261848576 )
# date: Wed Nov 14 09:28:32 +0000 2018
# hashtags: #python
# 2
# 1
# We are looking for a #DataScientist! Permanent position in beautiful Gothenburg. Working in an awesome project abou… https://t.co/g8jRobW85Y
# --------------------------------------------------------------
# account: (fullname: #AndroidDev href: /androiddevRTbot id: 708893361860517888 )
# date: Wed Nov 14 09:28:02 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…
# --------------------------------------------------------------
# account: (fullname: React Developer href: /_reactdev id: 812555214024740865 )
# date: Wed Nov 14 09:27:19 +0000 2018
# hashtags: #python
# 0
# 8
# RT @LanaBintadiaz: " TOP "
# Rest api testing using Postman tool
# #Udemy #Coupon #CodeRedLive #Programming #Engineering #WebDev #AndroidDev #…

# %%
import tweepy
import key

consumer_key = key.CK
consumer_secret = key.CS
access_key = key.AT
access_secret = key.AS

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)
for tweet in tweepy.Cursor(api.user_timeline,screen_name = "@Twitter").items(30):
    print('-------------------------------------------')
    print('full_name:',tweet.user.name,"href:",("/"+tweet.user.screen_name).strip(),"id:",tweet.user.id)
    print("date:",tweet.created_at)
    if tweet.entities['hashtags'] ==[]:
        print('None')
    else:
        print(tweet.entities['hashtags'][0]['text'])
    print(tweet.favorite_count)
    print(tweet.retweet_count)
    print(tweet.text.replace('\n',''))
# Out:
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:26:21
# None
# 64
# 3
# @ny_gal10 😎
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:10:41
# None
# 447
# 9
# @ohaniceyt That happened
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:07:57
# None
# 295
# 16
# @WaitThatsAdam https://t.co/yR23g0RsGD
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:06:57
# None
# 12293
# 1919
# A subtweet
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 15:02:35
# ForTheThrone
# 12156
# 3428
# ==(_____________________________)==         |          It's time to Tweet           |       #ForTheThrone… https://t.co/ailAW8ZQGu
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:53
# None
# 23
# 0
# @DisIsBuck Do it
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:32
# None
# 3
# 0
# @a_nice_frog Logging in when you're logged in
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:12
# None
# 2329
# 222
# @C_millz6 Stay on Twitter and you'll never have to answer the text
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:50
# None
# 10
# 1
# @brookemiccio We really do love that
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:31
# None
# 9
# 4
# @kamz26 Twitter friends are forever friends
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:13
# None
# 9
# 1
# @TheEmekaDiala 100%
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:54
# None
# 87
# 13
# @Biisi96 Strangers ➡️ friends in a Twitter minute
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:33
# None
# 11
# 0
# @taramassicotte Close enough
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:13
# None
# 3
# 1
# @Cute_Olodo_NG Gotta Tweet it earlier next time
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:02:46
# None
# 14
# 1
# @tonytx4_ They're a staple
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 20:32:15
# None
# 108
# 31
# @Dictionarycom 👆
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 19:09:19
# None
# 5
# 0
# @SuperRetina Carpe diem
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 19:01:16
# None
# 7
# 1
# @Mizz_Mary_Mac https://t.co/nuwDD2b6mV
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:47:52
# None
# 4
# 1
# @RPSashaBanksWWE So meta
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:31:07
# None
# 191
# 4
# @NishwanAbbas @waddey Or is it that other thing?
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:10:16
# None
# 352
# 6
# @anche_meno Like you did last summer
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:06:22
# None
# 613
# 34
# @usernameisdean What's your patronus?
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:04:22
# None
# 663
# 15
# @big_benford Nope, talking to you
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 17:59:55
# None
# 45245
# 7857
# Twitter, do your thing.
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:27:32
# None
# 16
# 0
# @HeartEyes4Brady Hi 💙
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:27:09
# None
# 26
# 0
# @BloodRedLiqueur What'd you find?
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:49
# None
# 410
# 3
# @TaliaMar Sunscreen
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:29
# None
# 12
# 2
# @fessyfitness Shady is a lifestyle
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:05
# None
# 66
# 7
# @majornelson He looks like this                          😶                         \    /… https://t.co/WFjOYH4r16
# -------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:25:42
# None
# 66
# 5
# @Hampton Nothing more than 280 characters
